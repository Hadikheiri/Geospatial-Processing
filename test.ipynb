# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahman75/Geospatial-Processing/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install atash --upgrade

# %%
from atash import *

# %%
connection = connect_to_openeo()
# Out:
# Authenticated using refresh token.
# Successfully connected and authenticated with OpenEO.

# %%
start_date, end_date = get_start_and_end_dates()
print(f"Start date: {start_date.strftime('%Y-%m-%d')}")
print(f"End date: {end_date.strftime('%Y-%m-%d')}")
# Out:
# Authenticated using refresh token.
# Successfully connected and authenticated with OpenEO.
# Enter the start date (YYYY-MM-DD): 2022-09-08
# Enter the end date (YYYY-MM-DD): 2022-09-15
# Start date: 2022-09-08
# End date: 2022-09-15

# %%
map = load_map()

# %%
map
# Out:
# Map(center=[45.4642, 9.19], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_…
# Rectangle Extent: {'west': -3.647118, 'south': 36.82605, 'east': -3.498802, 'north': 36.921352}

# %%
extent = {"west": map.west, "south": map.south, "east": map.east, "north": map.north}

# %%
load_pre_ndvi(connection, extent, start_date, end_date)

# %%
plot_pre_ndvi()

# %%
load_post_ndvi(connection, extent, start_date, end_date)

# %%
load_pre_nbr(connection, extent, start_date, end_date)

# %%
post_nbr(connection, extent, start_date, end_date)

# %%
fire_detector_nbr()

# %%
fire_area_nbr()

# %%
fire_area_ndvi()

# %%
severity_ndvi()
# Out:
# Area (km²) in Fire NDVI mode (excluding water):
# Unburned: 686.73 km²
# Low Severity: 5.64 km²
# Moderate Severity: 13.65 km²
# Moderate High Severity: 4.76 km²
# High Severity: 0.01 km²
#
# Total Fire Area (km²): 24.05 km²

# %%
severity_nbr()
# Out:
# Area (km²) in Fire mode (NBR, Excluding Water):
# Unburned: 661.48 km²
# Low Severity: 14.35 km²
# Moderate Severity: 24.18 km²
# Moderate High Severity: 9.32 km²
# High Severity: 1.45 km²
#
# Total Fire Area (km²): 49.30 km²

# %%
fire_severity_multiclass()
# Out:
# Fire-Affected Area by Severity (km²):
# Unburned: 669.39 km²
# Low Severity: 6.53 km²
# Moderate Severity: 24.10 km²
# Moderate High Severity: 9.32 km²
# High Severity: 1.45 km²
#
# Total Fire Area (km²): 41.39 km²

# %%
severity_kmeans()
# Out:
# Cluster 2 Area (km²): 166.43 km²
# Cluster 3 Area (km²): 45.63 km²
# Cluster 4 Area (km²): 76.89 km²
# Cluster 5 Area (km²): 338.12 km²
